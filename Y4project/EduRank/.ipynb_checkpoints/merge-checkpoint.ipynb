# %%
import pandas as pd
import numpy as np
import os

# %%
questions = pd.read_csv(os.path.join('EdNet-Contents', 'contents', 'questions.csv'))
lectures =  pd.read_csv(os.path.join('EdNet-Contents', 'contents', 'lectures.csv'))
lectures.rename(columns = {'part':'part_l'}, inplace = True)

kt3_files = os.listdir('KT1')
kt3_paths = [os.path.join('KT1', file) for file in kt3_files]

# %% [markdown]
# ### Merging csvs

# %%
def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

# %%
part = 0

for paths, files in zip(chunks(kt3_paths, 100000), chunks(kt3_files, 100000)):
    li = []
    kt3 = pd.DataFrame()
    for i, path in enumerate(paths):
        user_df = pd.read_csv(path)
        username = files[i].replace(".csv", "")
        user_df['username'] = username
        li.append(user_df)
    # Concatenanting user dfs
    kt3 = pd.concat(li, axis = 0 , ignore_index = True)
    kt3.to_csv('KT3_csv_large/KT3_part{}.csv'.format(part))
    part += 1

# %%
path1=kt3_paths[:100000]
path2=kt3_paths[100000:200000]
path3=kt3_paths[200000:]
file1=kt3_files[:100000]
file2=kt3_files[100000:200000]
file3=kt3_files[200000:]

# %%
li = []
kt3 = pd.DataFrame()
for i, path in enumerate(path3):
    if(i%1000==0):
        print(i)
    user_df = pd.read_csv(path)
    username = file3[i].replace(".csv", "")
    user_df['username'] = username
    li.append(user_df)
# Concatenanting user dfs
kt3 = pd.concat(li, axis = 0 , ignore_index = True)
kt3.to_csv('KT3_csv_large/KT3_part{}.csv'.format(2))
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000

# %%
enumerate(path1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-fbbb16d31c8c> in <module>
# ----> 1 enumerate(path1)[0]
#
# TypeError: 'enumerate' object is not subscriptable

# %%
path1
# Out:
# ['KT3\\u1.csv',
#  'KT3\\u10.csv',
#  'KT3\\u100.csv',
#  'KT3\\u1000.csv',
#  'KT3\\u10004.csv',
#  'KT3\\u100043.csv',
#  'KT3\\u10005.csv',
#  'KT3\\u1001.csv',
#  'KT3\\u10010.csv',
#  'KT3\\u10011.csv',
#  'KT3\\u10013.csv',
#  'KT3\\u10014.csv',
#  'KT3\\u10015.csv',
#  'KT3\\u10019.csv',
#  'KT3\\u1002.csv',
#  'KT3\\u10020.csv',
#  'KT3\\u10021.csv',
#  'KT3\\u10026.csv',
#  'KT3\\u10028.csv',
#  'KT3\\u1003.csv',
#  'KT3\\u10030.csv',
#  'KT3\\u10032.csv',
#  'KT3\\u10033.csv',
#  'KT3\\u10037.csv',
#  'KT3\\u10044.csv',
#  'KT3\\u10045.csv',
#  'KT3\\u10046.csv',
#  'KT3\\u10049.csv',
#  'KT3\\u1005.csv',
#  'KT3\\u10050.csv',
#  'KT3\\u10052.csv',
#  'KT3\\u10056.csv',
#  'KT3\\u10057.csv',
#  'KT3\\u10058.csv',
#  'KT3\\u10059.csv',
#  'KT3\\u1006.csv',
#  'KT3\\u10060.csv',
#  'KT3\\u10062.csv',
#  'KT3\\u10064.csv',
#  'KT3\\u1007.csv',
#  'KT3\\u10071.csv',
#  'KT3\\u10075.csv',
#  'KT3\\u10076.csv',
#  'KT3\\u10077.csv',
#  'KT3\\u10079.csv',
#  'KT3\\u1008.csv',
#  'KT3\\u10080.csv',
#  'KT3\\u10082.csv',
#  'KT3\\u10085.csv',
#  'KT3\\u10086.csv',
#  'KT3\\u10089.csv',
#  'KT3\\u1009.csv',
#  'KT3\\u10090.csv',
#  'KT3\\u10094.csv',
#  'KT3\\u10096.csv',
#  'KT3\\u10097.csv',
#  'KT3\\u10099.csv',
#  'KT3\\u101.csv',
#  'KT3\\u1010.csv',
#  'KT3\\u10101.csv',
#  'KT3\\u10104.csv',
#  'KT3\\u10105.csv',
#  'KT3\\u10106.csv',
#  'KT3\\u10107.csv',
#  'KT3\\u10109.csv',
#  'KT3\\u1011.csv',
#  'KT3\\u10110.csv',
#  'KT3\\u10114.csv',
#  'KT3\\u10116.csv',
#  'KT3\\u10119.csv',
#  'KT3\\u1012.csv',
#  'KT3\\u10120.csv',
#  'KT3\\u10122.csv',
#  'KT3\\u10123.csv',
#  'KT3\\u10128.csv',
#  'KT3\\u1013.csv',
#  'KT3\\u10130.csv',
#  'KT3\\u10132.csv',
#  'KT3\\u10134.csv',
#  'KT3\\u10136.csv',
#  'KT3\\u10137.csv',
#  'KT3\\u10138.csv',
#  'KT3\\u10139.csv',
#  'KT3\\u1014.csv',
#  'KT3\\u10141.csv',
#  'KT3\\u10143.csv',
#  'KT3\\u10147.csv',
#  'KT3\\u10149.csv',
#  'KT3\\u1015.csv',
#  'KT3\\u10150.csv',
#  'KT3\\u10151.csv',
#  'KT3\\u10153.csv',
#  'KT3\\u10155.csv',
#  'KT3\\u10156.csv',
#  'KT3\\u10158.csv',
#  'KT3\\u10159.csv',
#  'KT3\\u1016.csv',
#  'KT3\\u10160.csv',
#  'KT3\\u10161.csv',
#  'KT3\\u10162.csv',
#  'KT3\\u10165.csv',
#  'KT3\\u1017.csv',
#  'KT3\\u10170.csv',
#  'KT3\\u10171.csv',
#  'KT3\\u10174.csv',
#  'KT3\\u10177.csv',
#  'KT3\\u10178.csv',
#  'KT3\\u10179.csv',
#  'KT3\\u1018.csv',
#  'KT3\\u10180.csv',
#  'KT3\\u10181.csv',
#  'KT3\\u10182.csv',
#  'KT3\\u10183.csv',
#  'KT3\\u1019.csv',
#  'KT3\\u10198.csv',
#  'KT3\\u10199.csv',
#  'KT3\\u102.csv',
#  'KT3\\u1020.csv',
#  'KT3\\u10200.csv',
#  'KT3\\u10201.csv',
#  'KT3\\u10204.csv',
#  'KT3\\u10205.csv',
#  'KT3\\u10206.csv',
#  'KT3\\u10207.csv',
#  'KT3\\u10208.csv',
#  'KT3\\u10209.csv',
#  'KT3\\u1021.csv',
#  'KT3\\u10210.csv',
#  'KT3\\u10211.csv',
#  'KT3\\u102122.csv',
#  'KT3\\u10213.csv',
#  'KT3\\u10214.csv',
#  'KT3\\u10217.csv',
#  'KT3\\u10218.csv',
#  'KT3\\u10219.csv',
#  'KT3\\u1022.csv',
#  'KT3\\u10224.csv',
#  'KT3\\u10225.csv',
#  'KT3\\u10226.csv',
#  'KT3\\u10231.csv',
#  'KT3\\u10232.csv',
#  'KT3\\u10233.csv',
#  'KT3\\u10235.csv',
#  'KT3\\u10236.csv',
#  'KT3\\u10237.csv',
#  'KT3\\u1024.csv',
#  'KT3\\u10240.csv',
#  'KT3\\u10242.csv',
#  'KT3\\u10245.csv',
#  'KT3\\u10246.csv',
#  'KT3\\u10248.csv',
#  'KT3\\u10250.csv',
#  'KT3\\u10251.csv',
#  'KT3\\u10252.csv',
#  'KT3\\u10253.csv',
#  'KT3\\u10255.csv',
#  'KT3\\u10256.csv',
#  'KT3\\u10257.csv',
#  'KT3\\u10258.csv',
#  'KT3\\u10259.csv',
#  'KT3\\u1026.csv',
#  'KT3\\u10260.csv',
#  'KT3\\u10263.csv',
#  'KT3\\u10265.csv',
#  'KT3\\u10268.csv',
#  'KT3\\u1027.csv',
#  'KT3\\u10270.csv',
#  'KT3\\u10271.csv',
#  'KT3\\u10272.csv',
#  'KT3\\u10273.csv',
#  'KT3\\u10274.csv',
#  'KT3\\u10275.csv',
#  'KT3\\u10276.csv',
#  'KT3\\u10277.csv',
#  'KT3\\u1028.csv',
#  'KT3\\u10283.csv',
#  'KT3\\u10284.csv',
#  'KT3\\u10285.csv',
#  'KT3\\u10288.csv',
#  'KT3\\u10289.csv',
#  'KT3\\u1029.csv',
#  'KT3\\u10291.csv',
#  'KT3\\u10293.csv',
#  'KT3\\u10294.csv',
#  'KT3\\u10295.csv',
#  'KT3\\u10296.csv',
#  'KT3\\u10297.csv',
#  'KT3\\u10298.csv',
#  'KT3\\u103.csv',
#  'KT3\\u1030.csv',
#  'KT3\\u10300.csv',
#  'KT3\\u10302.csv',
#  'KT3\\u10303.csv',
#  'KT3\\u10306.csv',
#  'KT3\\u10307.csv',
#  'KT3\\u10308.csv',
#  'KT3\\u1031.csv',
#  'KT3\\u10312.csv',
#  'KT3\\u10314.csv',
#  'KT3\\u10315.csv',
#  'KT3\\u10316.csv',
#  'KT3\\u10318.csv',
#  'KT3\\u10319.csv',
#  'KT3\\u1032.csv',
#  'KT3\\u10321.csv',
#  'KT3\\u10322.csv',
#  'KT3\\u10323.csv',
#  'KT3\\u10326.csv',
#  'KT3\\u10329.csv',
#  'KT3\\u1033.csv',
#  'KT3\\u10332.csv',
#  'KT3\\u10333.csv',
#  'KT3\\u10334.csv',
#  'KT3\\u10336.csv',
#  'KT3\\u10337.csv',
#  'KT3\\u10339.csv',
#  'KT3\\u1034.csv',
#  'KT3\\u10340.csv',
#  'KT3\\u10341.csv',
#  'KT3\\u10342.csv',
#  'KT3\\u10344.csv',
#  'KT3\\u10345.csv',
#  'KT3\\u10346.csv',
#  'KT3\\u10347.csv',
#  'KT3\\u10348.csv',
#  'KT3\\u1035.csv',
#  'KT3\\u10350.csv',
#  'KT3\\u10351.csv',
#  'KT3\\u10354.csv',
#  'KT3\\u10357.csv',
#  'KT3\\u10359.csv',
#  'KT3\\u1036.csv',
#  'KT3\\u10360.csv',
#  'KT3\\u10363.csv',
#  'KT3\\u10366.csv',
#  'KT3\\u10367.csv',
#  'KT3\\u10368.csv',
#  'KT3\\u10369.csv',
#  'KT3\\u1037.csv',
#  'KT3\\u10370.csv',
#  'KT3\\u10371.csv',
#  'KT3\\u10374.csv',
#  'KT3\\u10375.csv',
#  'KT3\\u10376.csv',
#  'KT3\\u10378.csv',
#  'KT3\\u10379.csv',
#  'KT3\\u1038.csv',
#  'KT3\\u10380.csv',
#  'KT3\\u10381.csv',
#  'KT3\\u10383.csv',
#  'KT3\\u10384.csv',
#  'KT3\\u10386.csv',
#  'KT3\\u10388.csv',
#  'KT3\\u10389.csv',
#  'KT3\\u1039.csv',
#  'KT3\\u10390.csv',
#  'KT3\\u10391.csv',
#  'KT3\\u10395.csv',
#  'KT3\\u10399.csv',
#  'KT3\\u104.csv',
#  'KT3\\u1040.csv',
#  'KT3\\u10400.csv',
#  'KT3\\u10401.csv',
#  'KT3\\u10403.csv',
#  'KT3\\u10404.csv',
#  'KT3\\u10405.csv',
#  'KT3\\u10407.csv',
#  'KT3\\u10409.csv',
#  'KT3\\u10410.csv',
#  'KT3\\u10411.csv',
#  'KT3\\u10415.csv',
#  'KT3\\u10416.csv',
#  'KT3\\u1042.csv',
#  'KT3\\u10420.csv',
#  'KT3\\u10424.csv',
#  'KT3\\u10426.csv',
#  'KT3\\u10427.csv',
#  'KT3\\u10428.csv',
#  'KT3\\u1043.csv',
#  'KT3\\u10430.csv',
#  'KT3\\u10432.csv',
#  'KT3\\u10433.csv',
#  'KT3\\u10434.csv',
#  'KT3\\u10435.csv',
#  'KT3\\u10436.csv',
#  'KT3\\u10438.csv',
#  'KT3\\u1044.csv',
#  'KT3\\u10442.csv',
#  'KT3\\u10443.csv',
#  'KT3\\u10444.csv',
#  'KT3\\u10445.csv',
#  'KT3\\u10447.csv',
#  'KT3\\u10448.csv',
#  'KT3\\u1045.csv',
#  'KT3\\u10450.csv',
#  'KT3\\u10454.csv',
#  'KT3\\u10455.csv',
#  'KT3\\u10456.csv',
#  'KT3\\u10459.csv',
#  'KT3\\u1046.csv',
#  'KT3\\u10460.csv',
#  'KT3\\u10464.csv',
#  'KT3\\u10465.csv',
#  'KT3\\u10468.csv',
#  'KT3\\u1047.csv',
#  'KT3\\u10471.csv',
#  'KT3\\u10472.csv',
#  'KT3\\u10476.csv',
#  'KT3\\u10477.csv',
#  'KT3\\u10478.csv',
#  'KT3\\u1048.csv',
#  'KT3\\u10480.csv',
#  'KT3\\u10483.csv',
#  'KT3\\u10485.csv',
#  'KT3\\u10486.csv',
#  'KT3\\u10487.csv',
#  'KT3\\u10488.csv',
#  'KT3\\u1049.csv',
#  'KT3\\u10490.csv',
#  'KT3\\u10491.csv',
#  'KT3\\u10492.csv',
#  'KT3\\u10493.csv',
#  'KT3\\u10494.csv',
#  'KT3\\u10496.csv',
#  'KT3\\u10497.csv',
#  'KT3\\u10499.csv',
#  'KT3\\u105.csv',
#  'KT3\\u1050.csv',
#  'KT3\\u10500.csv',
#  'KT3\\u10502.csv',
#  'KT3\\u10506.csv',
#  'KT3\\u10507.csv',
#  'KT3\\u10508.csv',
#  'KT3\\u10509.csv',
#  'KT3\\u1051.csv',
#  'KT3\\u10514.csv',
#  'KT3\\u10515.csv',
#  'KT3\\u10516.csv',
#  'KT3\\u10517.csv',
#  'KT3\\u10518.csv',
#  'KT3\\u1052.csv',
#  'KT3\\u10520.csv',
#  'KT3\\u10521.csv',
#  'KT3\\u10523.csv',
#  'KT3\\u10525.csv',
#  'KT3\\u10527.csv',
#  'KT3\\u10529.csv',
#  'KT3\\u1053.csv',
#  'KT3\\u10530.csv',
#  'KT3\\u10531.csv',
#  'KT3\\u10533.csv',
#  'KT3\\u10535.csv',
#  'KT3\\u10537.csv',
#  'KT3\\u10538.csv',
#  'KT3\\u1054.csv',
#  'KT3\\u10540.csv',
#  'KT3\\u10541.csv',
#  'KT3\\u10543.csv',
#  'KT3\\u1055.csv',
#  'KT3\\u10551.csv',
#  'KT3\\u10553.csv',
#  'KT3\\u10554.csv',
#  'KT3\\u10555.csv',
#  'KT3\\u10556.csv',
#  'KT3\\u10558.csv',
#  'KT3\\u10559.csv',
#  'KT3\\u1056.csv',
#  'KT3\\u10560.csv',
#  'KT3\\u10563.csv',
#  'KT3\\u10565.csv',
#  'KT3\\u10566.csv',
#  'KT3\\u10567.csv',
#  'KT3\\u10569.csv',
#  'KT3\\u1057.csv',
#  'KT3\\u10572.csv',
#  'KT3\\u10573.csv',
#  'KT3\\u10574.csv',
#  'KT3\\u10577.csv',
#  'KT3\\u10578.csv',
#  'KT3\\u1058.csv',
#  'KT3\\u10580.csv',
#  'KT3\\u10581.csv',
#  'KT3\\u10587.csv',
#  'KT3\\u1059.csv',
#  'KT3\\u10591.csv',
#  'KT3\\u10592.csv',
#  'KT3\\u10593.csv',
#  'KT3\\u10594.csv',
#  'KT3\\u10598.csv',
#  'KT3\\u10599.csv',
#  'KT3\\u106.csv',
#  'KT3\\u1060.csv',
#  'KT3\\u10601.csv',
#  'KT3\\u10604.csv',
#  'KT3\\u10607.csv',
#  'KT3\\u10608.csv',
#  'KT3\\u10609.csv',
#  'KT3\\u1061.csv',
#  'KT3\\u10610.csv',
#  'KT3\\u10613.csv',
#  'KT3\\u10617.csv',
#  'KT3\\u10618.csv',
#  'KT3\\u10619.csv',
#  'KT3\\u1062.csv',
#  'KT3\\u10620.csv',
#  'KT3\\u10621.csv',
#  'KT3\\u10622.csv',
#  'KT3\\u10623.csv',
#  'KT3\\u10626.csv',
#  'KT3\\u10628.csv',
#  'KT3\\u10629.csv',
#  'KT3\\u1063.csv',
#  'KT3\\u10631.csv',
#  'KT3\\u10636.csv',
#  'KT3\\u10637.csv',
#  'KT3\\u10638.csv',
#  'KT3\\u1064.csv',
#  'KT3\\u10640.csv',
#  'KT3\\u10641.csv',
#  'KT3\\u10642.csv',
#  'KT3\\u10645.csv',
#  'KT3\\u1065.csv',
#  'KT3\\u10651.csv',
#  'KT3\\u10653.csv',
#  'KT3\\u10656.csv',
#  'KT3\\u10658.csv',
#  'KT3\\u10660.csv',
#  'KT3\\u10661.csv',
#  'KT3\\u10662.csv',
#  'KT3\\u10665.csv',
#  'KT3\\u10666.csv',
#  'KT3\\u1067.csv',
#  'KT3\\u10671.csv',
#  'KT3\\u10674.csv',
#  'KT3\\u1068.csv',
#  'KT3\\u10680.csv',
#  'KT3\\u10681.csv',
#  'KT3\\u10683.csv',
#  'KT3\\u10684.csv',
#  'KT3\\u10685.csv',
#  'KT3\\u10686.csv',
#  'KT3\\u10687.csv',
#  'KT3\\u10688.csv',
#  'KT3\\u1069.csv',
#  'KT3\\u10690.csv',
#  'KT3\\u10691.csv',
#  'KT3\\u10692.csv',
#  'KT3\\u10693.csv',
#  'KT3\\u10694.csv',
#  'KT3\\u10695.csv',
#  'KT3\\u10696.csv',
#  'KT3\\u10698.csv',
#  'KT3\\u10699.csv',
#  'KT3\\u107.csv',
#  'KT3\\u1070.csv',
#  'KT3\\u10701.csv',
#  'KT3\\u10703.csv',
#  'KT3\\u10704.csv',
#  'KT3\\u10707.csv',
#  'KT3\\u10710.csv',
#  'KT3\\u10714.csv',
#  'KT3\\u10715.csv',
#  'KT3\\u10716.csv',
#  'KT3\\u10717.csv',
#  'KT3\\u10719.csv',
#  'KT3\\u10720.csv',
#  'KT3\\u10721.csv',
#  'KT3\\u10722.csv',
#  'KT3\\u10724.csv',
#  'KT3\\u10726.csv',
#  'KT3\\u10727.csv',
#  'KT3\\u10728.csv',
#  'KT3\\u1073.csv',
#  'KT3\\u10730.csv',
#  'KT3\\u10731.csv',
#  'KT3\\u10733.csv',
#  'KT3\\u10736.csv',
#  'KT3\\u10739.csv',
#  'KT3\\u1074.csv',
#  'KT3\\u10740.csv',
#  'KT3\\u10741.csv',
#  'KT3\\u10742.csv',
#  'KT3\\u10743.csv',
#  'KT3\\u10744.csv',
#  'KT3\\u10745.csv',
#  'KT3\\u10747.csv',
#  'KT3\\u10749.csv',
#  'KT3\\u1075.csv',
#  'KT3\\u10755.csv',
#  'KT3\\u10758.csv',
#  'KT3\\u1076.csv',
#  'KT3\\u10760.csv',
#  'KT3\\u10761.csv',
#  'KT3\\u10762.csv',
#  'KT3\\u10763.csv',
#  'KT3\\u10765.csv',
#  'KT3\\u10766.csv',
#  'KT3\\u10767.csv',
#  'KT3\\u10768.csv',
#  'KT3\\u10769.csv',
#  'KT3\\u1077.csv',
#  'KT3\\u10771.csv',
#  'KT3\\u10772.csv',
#  'KT3\\u10773.csv',
#  'KT3\\u10775.csv',
#  'KT3\\u10776.csv',
#  'KT3\\u10777.csv',
#  'KT3\\u1078.csv',
#  'KT3\\u10780.csv',
#  'KT3\\u10781.csv',
#  'KT3\\u10782.csv',
#  'KT3\\u10783.csv',
#  'KT3\\u10785.csv',
#  'KT3\\u10787.csv',
#  'KT3\\u10789.csv',
#  'KT3\\u1079.csv',
#  'KT3\\u10790.csv',
#  'KT3\\u10793.csv',
#  'KT3\\u10794.csv',
#  'KT3\\u10797.csv',
#  'KT3\\u10798.csv',
#  'KT3\\u108.csv',
#  'KT3\\u1080.csv',
#  'KT3\\u10800.csv',
#  'KT3\\u10801.csv',
#  'KT3\\u10803.csv',
#  'KT3\\u10805.csv',
#  'KT3\\u10806.csv',
#  'KT3\\u10807.csv',
#  'KT3\\u10808.csv',
#  'KT3\\u10809.csv',
#  'KT3\\u1081.csv',
#  'KT3\\u10810.csv',
#  'KT3\\u10812.csv',
#  'KT3\\u10813.csv',
#  'KT3\\u10816.csv',
#  'KT3\\u10817.csv',
#  'KT3\\u10818.csv',
#  'KT3\\u10819.csv',
#  'KT3\\u1082.csv',
#  'KT3\\u10820.csv',
#  'KT3\\u10822.csv',
#  'KT3\\u10823.csv',
#  'KT3\\u10824.csv',
#  'KT3\\u10825.csv',
#  'KT3\\u10826.csv',
#  'KT3\\u10827.csv',
#  'KT3\\u10828.csv',
#  'KT3\\u1083.csv',
#  'KT3\\u10834.csv',
#  'KT3\\u10837.csv',
#  'KT3\\u10838.csv',
#  'KT3\\u10839.csv',
#  'KT3\\u1084.csv',
#  'KT3\\u10842.csv',
#  'KT3\\u10844.csv',
#  'KT3\\u10846.csv',
#  'KT3\\u10847.csv',
#  'KT3\\u10849.csv',
#  'KT3\\u1085.csv',
#  'KT3\\u10850.csv',
#  'KT3\\u10851.csv',
#  'KT3\\u10853.csv',
#  'KT3\\u10854.csv',
#  'KT3\\u10856.csv',
#  'KT3\\u10857.csv',
#  'KT3\\u10859.csv',
#  'KT3\\u1086.csv',
#  'KT3\\u10863.csv',
#  'KT3\\u10865.csv',
#  'KT3\\u10866.csv',
#  'KT3\\u10868.csv',
#  'KT3\\u10869.csv',
#  'KT3\\u1087.csv',
#  'KT3\\u10871.csv',
#  'KT3\\u10875.csv',
#  'KT3\\u10878.csv',
#  'KT3\\u1088.csv',
#  'KT3\\u10881.csv',
#  'KT3\\u10882.csv',
#  'KT3\\u10883.csv',
#  'KT3\\u10889.csv',
#  'KT3\\u1089.csv',
#  'KT3\\u10892.csv',
#  'KT3\\u10895.csv',
#  'KT3\\u10896.csv',
#  'KT3\\u10898.csv',
#  'KT3\\u10899.csv',
#  'KT3\\u1090.csv',
#  'KT3\\u10900.csv',
#  'KT3\\u10906.csv',
#  'KT3\\u10908.csv',
#  'KT3\\u10909.csv',
#  'KT3\\u1091.csv',
#  'KT3\\u10912.csv',
#  'KT3\\u10913.csv',
#  'KT3\\u10916.csv',
#  'KT3\\u10918.csv',
#  'KT3\\u10919.csv',
#  'KT3\\u1092.csv',
#  'KT3\\u10923.csv',
#  'KT3\\u10926.csv',
#  'KT3\\u10927.csv',
#  'KT3\\u10928.csv',
#  'KT3\\u10929.csv',
#  'KT3\\u10932.csv',
#  'KT3\\u10933.csv',
#  'KT3\\u10935.csv',
#  'KT3\\u1094.csv',
#  'KT3\\u10941.csv',
#  'KT3\\u10942.csv',
#  'KT3\\u10943.csv',
#  'KT3\\u10946.csv',
#  'KT3\\u10948.csv',
#  'KT3\\u10949.csv',
#  'KT3\\u1095.csv',
#  'KT3\\u10950.csv',
#  'KT3\\u10952.csv',
#  'KT3\\u10953.csv',
#  'KT3\\u10955.csv',
#  'KT3\\u10956.csv',
#  'KT3\\u10957.csv',
#  'KT3\\u10958.csv',
#  'KT3\\u1096.csv',
#  'KT3\\u10960.csv',
#  'KT3\\u10961.csv',
#  'KT3\\u10962.csv',
#  'KT3\\u10963.csv',
#  'KT3\\u10964.csv',
#  'KT3\\u10965.csv',
#  'KT3\\u10966.csv',
#  'KT3\\u1097.csv',
#  'KT3\\u10973.csv',
#  'KT3\\u10974.csv',
#  'KT3\\u10978.csv',
#  'KT3\\u10979.csv',
#  'KT3\\u1098.csv',
#  'KT3\\u10980.csv',
#  'KT3\\u10981.csv',
#  'KT3\\u10982.csv',
#  'KT3\\u10983.csv',
#  'KT3\\u10985.csv',
#  'KT3\\u10986.csv',
#  'KT3\\u10987.csv',
#  'KT3\\u10988.csv',
#  'KT3\\u10989.csv',
#  'KT3\\u1099.csv',
#  'KT3\\u10990.csv',
#  'KT3\\u10993.csv',
#  'KT3\\u10998.csv',
#  'KT3\\u11.csv',
#  'KT3\\u1100.csv',
#  'KT3\\u11002.csv',
#  'KT3\\u11004.csv',
#  'KT3\\u11006.csv',
#  'KT3\\u11007.csv',
#  'KT3\\u11008.csv',
#  'KT3\\u1101.csv',
#  'KT3\\u11011.csv',
#  'KT3\\u11013.csv',
#  'KT3\\u1102.csv',
#  'KT3\\u11021.csv',
#  'KT3\\u11022.csv',
#  'KT3\\u11024.csv',
#  'KT3\\u11025.csv',
#  'KT3\\u11026.csv',
#  'KT3\\u1103.csv',
#  'KT3\\u11030.csv',
#  'KT3\\u11031.csv',
#  'KT3\\u11033.csv',
#  'KT3\\u11036.csv',
#  'KT3\\u11039.csv',
#  'KT3\\u1104.csv',
#  'KT3\\u11040.csv',
#  'KT3\\u11042.csv',
#  'KT3\\u11043.csv',
#  'KT3\\u11044.csv',
#  'KT3\\u11045.csv',
#  'KT3\\u11046.csv',
#  'KT3\\u11047.csv',
#  'KT3\\u11049.csv',
#  'KT3\\u1105.csv',
#  'KT3\\u11052.csv',
#  'KT3\\u11053.csv',
#  'KT3\\u11054.csv',
#  'KT3\\u11055.csv',
#  'KT3\\u11056.csv',
#  'KT3\\u11057.csv',
#  'KT3\\u11059.csv',
#  'KT3\\u1106.csv',
#  'KT3\\u11060.csv',
#  'KT3\\u11062.csv',
#  'KT3\\u11064.csv',
#  'KT3\\u11067.csv',
#  'KT3\\u11068.csv',
#  'KT3\\u1107.csv',
#  'KT3\\u11071.csv',
#  'KT3\\u11072.csv',
#  'KT3\\u11073.csv',
#  'KT3\\u11075.csv',
#  'KT3\\u11078.csv',
#  'KT3\\u11079.csv',
#  'KT3\\u1108.csv',
#  'KT3\\u11083.csv',
#  'KT3\\u11086.csv',
#  'KT3\\u11087.csv',
#  'KT3\\u11088.csv',
#  'KT3\\u11089.csv',
#  'KT3\\u1109.csv',
#  'KT3\\u11091.csv',
#  'KT3\\u11093.csv',
#  'KT3\\u11096.csv',
#  'KT3\\u111.csv',
#  'KT3\\u1110.csv',
#  'KT3\\u11100.csv',
#  'KT3\\u11102.csv',
#  'KT3\\u11103.csv',
#  'KT3\\u11104.csv',
#  'KT3\\u11105.csv',
#  'KT3\\u11106.csv',
#  'KT3\\u11108.csv',
#  'KT3\\u11109.csv',
#  'KT3\\u1111.csv',
#  'KT3\\u11110.csv',
#  'KT3\\u11111.csv',
#  'KT3\\u11112.csv',
#  'KT3\\u11116.csv',
#  'KT3\\u11118.csv',
#  'KT3\\u11119.csv',
#  'KT3\\u1112.csv',
#  'KT3\\u11120.csv',
#  'KT3\\u11121.csv',
#  'KT3\\u11122.csv',
#  'KT3\\u11124.csv',
#  'KT3\\u1113.csv',
#  'KT3\\u11132.csv',
#  'KT3\\u11135.csv',
#  'KT3\\u11137.csv',
#  'KT3\\u1114.csv',
#  'KT3\\u11144.csv',
#  'KT3\\u11147.csv',
#  'KT3\\u11148.csv',
#  'KT3\\u11149.csv',
#  'KT3\\u1115.csv',
#  'KT3\\u11151.csv',
#  'KT3\\u11153.csv',
#  'KT3\\u11154.csv',
#  'KT3\\u11155.csv',
#  'KT3\\u11156.csv',
#  'KT3\\u1116.csv',
#  'KT3\\u11164.csv',
#  'KT3\\u11165.csv',
#  'KT3\\u11168.csv',
#  'KT3\\u11169.csv',
#  'KT3\\u1117.csv',
#  'KT3\\u11170.csv',
#  'KT3\\u11172.csv',
#  'KT3\\u11176.csv',
#  'KT3\\u11178.csv',
#  'KT3\\u11179.csv',
#  'KT3\\u1118.csv',
#  'KT3\\u11181.csv',
#  'KT3\\u11182.csv',
#  'KT3\\u11183.csv',
#  'KT3\\u11189.csv',
#  'KT3\\u1119.csv',
#  'KT3\\u11190.csv',
#  'KT3\\u11191.csv',
#  'KT3\\u11192.csv',
#  'KT3\\u11194.csv',
#  'KT3\\u11197.csv',
#  'KT3\\u11198.csv',
#  'KT3\\u112.csv',
#  'KT3\\u1120.csv',
#  'KT3\\u11201.csv',
#  'KT3\\u11204.csv',
#  'KT3\\u11209.csv',
#  'KT3\\u1121.csv',
#  'KT3\\u11210.csv',
#  'KT3\\u11215.csv',
#  'KT3\\u11217.csv',
#  'KT3\\u11219.csv',
#  'KT3\\u11220.csv',
#  'KT3\\u11221.csv',
#  'KT3\\u11223.csv',
#  'KT3\\u11226.csv',
#  'KT3\\u11227.csv',
#  'KT3\\u11228.csv',
#  'KT3\\u11229.csv',
#  'KT3\\u1123.csv',
#  'KT3\\u11230.csv',
#  'KT3\\u11231.csv',
#  'KT3\\u11236.csv',
#  'KT3\\u11238.csv',
#  'KT3\\u11239.csv',
#  'KT3\\u1124.csv',
#  'KT3\\u11240.csv',
#  'KT3\\u11241.csv',
#  'KT3\\u11243.csv',
#  'KT3\\u11244.csv',
#  'KT3\\u11247.csv',
#  'KT3\\u11248.csv',
#  'KT3\\u11249.csv',
#  'KT3\\u11252.csv',
#  'KT3\\u11253.csv',
#  'KT3\\u11255.csv',
#  'KT3\\u11258.csv',
#  'KT3\\u11259.csv',
#  'KT3\\u1126.csv',
#  'KT3\\u11260.csv',
#  'KT3\\u11262.csv',
#  'KT3\\u11263.csv',
#  'KT3\\u11264.csv',
#  'KT3\\u11265.csv',
#  'KT3\\u11269.csv',
#  'KT3\\u1127.csv',
#  'KT3\\u11272.csv',
#  'KT3\\u11273.csv',
#  'KT3\\u11278.csv',
#  'KT3\\u11279.csv',
#  'KT3\\u1128.csv',
#  'KT3\\u11281.csv',
#  'KT3\\u11282.csv',
#  'KT3\\u11283.csv',
#  'KT3\\u11284.csv',
#  'KT3\\u11285.csv',
#  'KT3\\u11286.csv',
#  'KT3\\u1129.csv',
#  'KT3\\u11294.csv',
#  'KT3\\u11296.csv',
#  'KT3\\u11297.csv',
#  'KT3\\u113.csv',
#  'KT3\\u1130.csv',
#  'KT3\\u11301.csv',
#  'KT3\\u11304.csv',
#  'KT3\\u11306.csv',
#  'KT3\\u11308.csv',
#  'KT3\\u1131.csv',
#  'KT3\\u11312.csv',
#  'KT3\\u11314.csv',
#  'KT3\\u11318.csv',
#  'KT3\\u1132.csv',
#  'KT3\\u11321.csv',
#  'KT3\\u11322.csv',
#  'KT3\\u11324.csv',
#  'KT3\\u11325.csv',
#  'KT3\\u11326.csv',
#  'KT3\\u11328.csv',
#  'KT3\\u11329.csv',
#  'KT3\\u1133.csv',
#  'KT3\\u11330.csv',
#  'KT3\\u11332.csv',
#  'KT3\\u11334.csv',
#  'KT3\\u11337.csv',
#  'KT3\\u1134.csv',
#  'KT3\\u11340.csv',
#  'KT3\\u11341.csv',
#  'KT3\\u11345.csv',
#  'KT3\\u11347.csv',
#  'KT3\\u1135.csv',
#  'KT3\\u11351.csv',
#  'KT3\\u11353.csv',
#  'KT3\\u11355.csv',
#  'KT3\\u1136.csv',
#  'KT3\\u11360.csv',
#  'KT3\\u11361.csv',
#  'KT3\\u11363.csv',
#  'KT3\\u11364.csv',
#  'KT3\\u11367.csv',
#  'KT3\\u11368.csv',
#  'KT3\\u1137.csv',
#  'KT3\\u11372.csv',
#  'KT3\\u11373.csv',
#  'KT3\\u1138.csv',
#  'KT3\\u11383.csv',
#  'KT3\\u11385.csv',
#  'KT3\\u11386.csv',
#  'KT3\\u11388.csv',
#  'KT3\\u11389.csv',
#  'KT3\\u1139.csv',
#  'KT3\\u11390.csv',
#  'KT3\\u11392.csv',
#  'KT3\\u11394.csv',
#  'KT3\\u11395.csv',
#  'KT3\\u11396.csv',
#  'KT3\\u11397.csv',
#  'KT3\\u114.csv',
#  'KT3\\u1140.csv',
#  'KT3\\u11400.csv',
#  'KT3\\u11401.csv',
#  'KT3\\u11403.csv',
#  'KT3\\u11405.csv',
#  'KT3\\u11406.csv',
#  'KT3\\u11407.csv',
#  'KT3\\u11408.csv',
#  'KT3\\u11409.csv',
#  'KT3\\u11410.csv',
#  'KT3\\u11411.csv',
#  'KT3\\u11412.csv',
#  'KT3\\u11415.csv',
#  'KT3\\u11416.csv',
#  'KT3\\u11417.csv',
#  'KT3\\u11419.csv',
#  'KT3\\u1142.csv',
#  'KT3\\u11421.csv',
#  'KT3\\u11423.csv',
#  'KT3\\u11424.csv',
#  'KT3\\u11425.csv',
#  'KT3\\u11427.csv',
#  'KT3\\u11428.csv',
#  'KT3\\u11429.csv',
#  'KT3\\u11432.csv',
#  'KT3\\u11433.csv',
#  'KT3\\u11436.csv',
#  'KT3\\u11438.csv',
#  'KT3\\u1144.csv',
#  'KT3\\u11441.csv',
#  'KT3\\u11443.csv',
#  'KT3\\u11444.csv',
#  'KT3\\u11447.csv',
#  'KT3\\u11448.csv',
#  'KT3\\u11449.csv',
#  'KT3\\u1145.csv',
#  'KT3\\u11451.csv',
#  'KT3\\u11454.csv',
#  'KT3\\u11457.csv',
#  'KT3\\u11459.csv',
#  'KT3\\u1146.csv',
#  'KT3\\u11460.csv',
#  'KT3\\u11461.csv',
#  'KT3\\u11462.csv',
#  'KT3\\u11463.csv',
#  'KT3\\u11464.csv',
#  'KT3\\u11465.csv',
#  'KT3\\u11467.csv',
#  'KT3\\u1147.csv',
#  'KT3\\u11470.csv',
#  'KT3\\u11471.csv',
#  'KT3\\u11475.csv',
#  'KT3\\u11478.csv',
#  'KT3\\u11479.csv',
#  'KT3\\u1148.csv',
#  'KT3\\u11483.csv',
#  'KT3\\u11484.csv',
#  'KT3\\u11487.csv',
#  'KT3\\u11488.csv',
#  'KT3\\u11489.csv',
#  'KT3\\u1149.csv',
#  'KT3\\u11490.csv',
#  'KT3\\u11491.csv',
#  'KT3\\u11492.csv',
#  'KT3\\u11493.csv',
#  'KT3\\u11496.csv',
#  'KT3\\u11497.csv',
#  'KT3\\u115.csv',
#  'KT3\\u1150.csv',
#  'KT3\\u11500.csv',
#  'KT3\\u11504.csv',
#  'KT3\\u11505.csv',
#  'KT3\\u11506.csv',
#  'KT3\\u11507.csv',
#  'KT3\\u11509.csv',
#  'KT3\\u1151.csv',
#  'KT3\\u11514.csv',
#  'KT3\\u11519.csv',
#  'KT3\\u1152.csv',
#  'KT3\\u11521.csv',
#  'KT3\\u11524.csv',
#  'KT3\\u11525.csv',
#  'KT3\\u11526.csv',
#  'KT3\\u11527.csv',
#  'KT3\\u11529.csv',
#  'KT3\\u11531.csv',
#  'KT3\\u11532.csv',
#  'KT3\\u11535.csv',
#  'KT3\\u11536.csv',
#  'KT3\\u11537.csv',
#  'KT3\\u1154.csv',
#  'KT3\\u11540.csv',
#  'KT3\\u11542.csv',
#  'KT3\\u11543.csv',
#  'KT3\\u11544.csv',
#  'KT3\\u11545.csv',
#  'KT3\\u11546.csv',
#  'KT3\\u11547.csv',
#  'KT3\\u11549.csv',
#  'KT3\\u1155.csv',
#  'KT3\\u11550.csv',
#  'KT3\\u11551.csv',
#  'KT3\\u11556.csv',
#  'KT3\\u11557.csv',
#  'KT3\\u11558.csv',
#  'KT3\\u11559.csv',
#  'KT3\\u1156.csv',
#  'KT3\\u11560.csv',
#  'KT3\\u11563.csv',
#  'KT3\\u11564.csv',
#  'KT3\\u11569.csv',
#  'KT3\\u1157.csv',
#  'KT3\\u11572.csv',
#  ...]
